# %% [markdown]
# <a href="https://colab.research.google.com/github/Robbysaidiii/MSIB_K2_AWANPINTAR/blob/main/Self_Learning_pelabelan_dan_pembuatan_WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Latihan Data Exploration NLP**
#
# NLP adalah cabang dari Artificial Intelligence yang berhubungan dengan interaksi antara mesin dan manusia menggunakan bahasa natural.
#
# Eksplorasi data merupakan langkah untuk memahami data sebelum dilakukan praproses. Pemahaman terhadap data yang akan di-mining dapat membantu dalam menentukan teknik-teknik pra-proses dan analisis data terhadap data sebelum dilakukan data mining.

# %% [markdown]
# ## **Import Library**

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# !pip install sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from wordcloud import WordCloud
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %% [markdown]
# Import data
# silahkan gunakan data yang sudah kalian ambil pada hari selasa, data berupa text yang diambil di twitter dengan topik tertentu
#
# atau bisa gunakan data yang disediakan
# [disini](https://drive.google.com/file/d/10sIjKMFBhBlp5W4zCWFwXDars2c7koyR/view?usp=sharing)

# %%
tweet = pd.read_csv('/content/bjorka.csv')
tweet
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6655119c0b3b> in <cell line: 1>()
# ----> 1 tweet = pd.read_csv('/content/bjorka.csv')
#       2 tweet
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/bjorka.csv'

# %%
tweets = tweet.iloc[0:300,:]
tweets
# Out:
#                timetweet                                           isitweet  \
# 0    2022-09-20 12:21:02  b'@wiragaksableng @iya_althaf Hahahaha.. Sdkit...
# 1    2022-09-20 12:20:48  b'RT @ismailfahmi: Ndak gini juga cara mainnya...
# 2    2022-09-20 12:20:18  b'RT @MMargani5: Akibat GONJANG-GANJING Kasus ...
# 3    2022-09-20 12:20:09  b'RT @HalimTeuku: Kata Bjorka bong: "Saya Hack...
# 4    2022-09-20 12:19:51  b'RT @rekomendasihitz: pastel outfit idea \xf0...
# ..                   ...                                                ...
# 295  2022-09-20 11:20:57                 b'@bjorkanismreal Real kah bjorka'
# 296  2022-09-20 11:20:00  b'"Halo nyonya, saya tidak punya banyak waktu ...
# 297  2022-09-20 11:19:59  b'RT @rekomendasihitz: pastel outfit idea \xf0...
# 298  2022-09-20 11:19:58  b'RT @tubbirfess: Polisi nyari bjorka 1 bulan ...
# 299  2022-09-20 11:19:40  b'RT @ismailfahmi: Ndak gini juga cara mainnya...
#
#      favcount  retwcount                   id             name
# 0           0          0  1572199152418975746      InginBebas6
# 1           0       1596  1572199092926943232     Daaan_Daaann
# 2           0        463  1572198968284839938          Tju_Lee
# 3           0          2  1572198930104078339         6undul0h
# 4           0         79  1572198853146968064   lonjwinkiyowoo
# ..        ...        ...                  ...              ...
# 295         0          0  1572184032909365249      friendly685
# 296         2          0  1572183791098941440      okezonenews
# 297         0         79  1572183787228004355   racunterusguis
# 298         0        590  1572183784312930304     tweetaje_aje
# 299         0       1596  1572183706768670722  AcehSelatanSatu
#
# [300 rows x 6 columns]

# %% [markdown]
# ##Fungsi Preprocessing
# Text preprocessing adalah suatu proses untuk menyeleksi data text agar menjadi lebih terstruktur lagi dengan melalui serangkaian tahapan yang meliputi tahapan case folding, tokenizing, filtering dan stemming. Tapi, sesungguhnya tidak ada aturan pasti tentang setiap tahapan dalam text preprocessing. Semua itu tergantung dengan jenis serta kondisi data yang kita miliki. Text preprocessing merupakan salah satu implementasi dari text mining. Text mining sendiri adalah suatu kegiatan menambang data, dimana data yang biasanya diambil berupa text yang bersumber dari dokumen-dokumen yang memiliki goals untuk mencari kata kunci yang mewakili dari sekumpulan dokumen tersebut sehingga nantinya dapat dilakukan analisa hubungan antara dokumen-dokumen tersebut.

# %%
def cleaningText(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text) # remove mentions
    text = re.sub(r'#[A-Za-z0-9]+', '', text) # remove hashtag
    text = re.sub(r'RT[\s]', '', text) # remove RT
    text = re.sub(r"http\S+", '', text) # remove link
    text = re.sub(r'[0-9]+', '', text) # remove numbers
    text = re.sub(r'B|b', '', text)
    text = re.sub(r'xexxa', '', text)

    text = text.replace('\n', ' ') # replace new line into space
    text = text.translate(str.maketrans('', '', string.punctuation)) # remove all punctuations
    text = text.strip(' ') # remove characters space from both left and right text
    return text

def casefoldingText(text): # Converting all the characters in a text into lower case
    text = text.lower()
    return text

def tokenizingText(text): # Tokenizing or splitting a string, text into a list of tokens
    text = word_tokenize(text)
    return text

def filteringText(text): # Remove stopwors in a text
    listStopwords = set(stopwords.words('indonesian'))
    filtered = []
    for txt in text:
        if txt not in listStopwords:
            filtered.append(txt)
    text = filtered
    return text

def stemmingText(text): # Reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    text = [stemmer.stem(word) for word in text]
    return text

def toSentence(list_words): # Convert list of words into sentence
    sentence = ' '.join(word for word in list_words)
    return sentence

# %% [markdown]
# ##Download Punkt
# Punkt dan stopword adalah corpus atau dataset yang disediakan oleh nltk yang akan banyak digunakan pada domain NLP

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ##Proses Preprocessing,
# Tahap ini adalah menjalankan fungsi Preprocessing data kita
#
# sebagai gambaran 4000 data sekitar 1.5 jam sabar ya

# %%
tweets['text_clean'] = tweets['isitweet'].apply(cleaningText)
tweets['text_clean'] = tweets['text_clean'].apply(casefoldingText)
tweets.drop(['isitweet'], axis = 1, inplace = True)

tweets['text_preprocessed'] = tweets['text_clean'].apply(tokenizingText)
tweets['text_preprocessed'] = tweets['text_preprocessed'].apply(filteringText)
tweets['text_preprocessed'] = tweets['text_preprocessed'].apply(stemmingText)

# drop duplicates/spams tweets
tweets.drop_duplicates(subset = 'text_clean', inplace = True)

# %% [markdown]
# ## Menampilkan kalimat yang sudah di preprocessing

# %%
tweets
# Out:
#                timetweet  favcount  retwcount                   id  \
# 0    2022-09-20 12:21:02         0          0  1572199152418975746
# 1    2022-09-20 12:20:48         0       1596  1572199092926943232
# 2    2022-09-20 12:20:18         0        463  1572198968284839938
# 3    2022-09-20 12:20:09         0          2  1572198930104078339
# 4    2022-09-20 12:19:51         0         79  1572198853146968064
# ..                   ...       ...        ...                  ...
# 290  2022-09-20 11:21:30         0        139  1572184171690487809
# 293  2022-09-20 11:21:20         0          0  1572184127692214273
# 294  2022-09-20 11:21:16         0          3  1572184110881472519
# 295  2022-09-20 11:20:57         0          0  1572184032909365249
# 296  2022-09-20 11:20:00         2          0  1572183791098941440
#
#                name                                         text_clean  \
# 0       InginBebas6  b althaf hahahaha sdkit pi lg ini sy ku pensiu...
# 1      Daaan_Daaann  b ndak gini juga cara mainnya omnndi eropa di ...
# 2           Tju_Lee  b akibat gonjangganjing kasus sambo amp bjorka...
# 3          6undul0h  b kata bjorka bong saya hacker mau beli akun t...
# 4    lonjwinkiyowoo  b pastel outfit idea xfxfxcxnnxexxthreadnnadam...
# ..              ...                                                ...
# 290       donrev670                              b bjorka jumat berkah
# 293     Iqbaleee11_     bjkt hallo mimin  abis ngumpul sama bjorka yak
# 294     apriannoor4  b bagaimana uu pdp dalam memerangkap para pemb...
# 295     friendly685                                  b real kah bjorka
# 296     okezonenews  bhalo nyonya saya tidak punya banyak waktu unt...
#
#                                      text_preprocessed
# 0    [b, althaf, hahahaha, sdkit, pi, lg, sy, ku, p...
# 1    [b, ndak, gin, main, omnndi, eropa, singapore,...
# 2    [b, akibat, gonjangganjing, sambo, amp, bjorka...
# 3    [b, bjorka, bong, hacker, beli, akun, tele, nn...
# 4    [b, pastel, outfit, idea, xfxfxcxnnxexxthreadn...
# ..                                                 ...
# 290                         [b, bjorka, jumat, berkah]
# 293   [bjkt, hallo, mimin, abis, ngumpul, bjorka, yak]
# 294  [b, uu, pdp, perangkap, pembombol, data, priba...
# 295                             [b, real, kah, bjorka]
# 296  [bhalo, nyonya, layan, cari, nama, tutup, buru...
#
# [146 rows x 7 columns]

# %% [markdown]
# ## Labeling dengan lexicon
# Pelabelan data adalah proses penambahan label ke data mentah untuk memberikan konteks atau makna pada data. Data berlabel kemudian digunakan untuk melatih model NLP untuk membuat prediksi atau memahami atau menghasilkan ucapan.
#
# pelabelan kali ini menggunakan lexicon sebagai pelabelan secara otomatis. Dalam klasifikasi berbasis leksikon, dokumen diberi label dengan membandingkan jumlah kata yang muncul dari dua leksikon yang berlawanan, seperti sentimen positif dan negatif.
#
# Sebelum menjalankan kode berikut silahkan download 2 file pendukung berikut:
#
# [Negatif](https://drive.google.com/file/d/1UBLrxmfFTEg1t9rHw6v-M5pJVRDWuyFH/view?usp=sharing)
#
# [Positif](https://drive.google.com/file/d/1JqpJ12JqiOMOJ5R0Gg4rz3Xbqe3j2-Om/view?usp=sharing)
#
# [Referensi](https://github.com/fajri91/InSet)

# %%
# Loads lexicon positive and negative data
lexicon_positive = dict()
import csv
with open('positive.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        lexicon_positive[row[0]] = int(row[1])

lexicon_negative = dict()
import csv
with open('negative.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        lexicon_negative[row[0]] = int(row[1])

# Function to determine sentiment polarity of tweets
def sentiment_analysis_lexicon_indonesia(text):
    #for word in text:
    score = 0
    for word in text:
        if (word in lexicon_positive):
            score = score + lexicon_positive[word]
    for word in text:
        if (word in lexicon_negative):
            score = score + lexicon_negative[word]
    polarity=''
    if (score > 0):
        polarity = 'positive'
    elif (score < 0):
        polarity = 'negative'
    else:
        polarity = 'neutral'
    return score, polarity

# %%
results = tweets['text_preprocessed'].apply(sentiment_analysis_lexicon_indonesia)
results = list(zip(*results))
tweets['polarity_score'] = results[0]
tweets['polarity'] = results[1]
print(tweets['polarity'].value_counts())

# Export to csv file
# Out:
# negative    73
# neutral     37
# positive    36
# Name: polarity, dtype: int64

# %% [markdown]
# ## Visualisasi Hasil sentiment

# %%
fig, ax = plt.subplots(figsize = (6, 6))
sizes = [count for count in tweets['polarity'].value_counts()]
labels = list(tweets['polarity'].value_counts().index)
explode = (0.1, 0, 0)
ax.pie(x = sizes, labels = labels, autopct = '%1.1f%%', explode = explode, textprops={'fontsize': 14})
ax.set_title(f'Sentiment Polarity on Tweets Data \n (total = {len(tweets.index)} tweets)', fontsize = 16, pad = 20)
plt.show()

# %%
pd.set_option('display.max_colwidth', 3000)
positive_tweets = tweets[tweets['polarity'] == 'positive']
positive_tweets = positive_tweets[['text_clean', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=False).reset_index(drop = True)
positive_tweets.index += 1
positive_tweets[0:10]
# Out:
#                                                                                                                                                                                                                                                           text_clean  \
# 1                                                                                                                                   b referensi one set ala korea checkna treadnnbjorka ngeringeri sedap suho masih pagi fikri seulgi happy birthday my love sexexxa
# 2                                                                                                                                                                                                   bdrama afi ga kelar kelar bisa minta tolong ke bjorka aja gasiii
# 3                                                                                                                                                                b rekomendasi sandal gemes nih guys xfxfxxd harga murah empuk amp lentur xfxfxxdnordernya disini ya
# 4                                                                                                                                                                                                                                              b bjorka jumat berkah
# 5                                                                                                                                                                   b percayalah anda tidak akan jadi presiden jangan buangbuang waktu sentil bjorka ke erick tohirn
# 6                                                                                                                                                              bafi  natalie terselamatkan oleh reza arap xfxfxaxanbesok siapa lagi yg trending bjorka sudah kelelep
# 7                                                                                                                                                                        b disinilah fungsinya bjorka nsehingga siapapun kelak tak percaya hasil rekapitulasi xfxfxx
# 8                                                                                                                            b rekomendasi sweater  outer kiyowoxexxxefxbxfnnxexxthreadnnnatalie miho bakti untuk negeri minggu gta  choi doha bjorka vmin andrxexxa
# 9   bmasih heboh bae ieu bjorka nu bisa ngabajak akun pamarentah beuh badeng eta fb kula baheula dibajak ku bjorka nyah haha nntah ngomongxcxb akun medsos kaka teteh pernah aya nu ngabajak teu beraha kali ganti akun komen amp req lagu pop di  brg kang  mudofar
# 10                                                                                                                             b xexcxa rekomendasi sweater kekinian under k xexcxannxexxthreadnnyoasobi senin hitc natalie  menit piala asia peningkatan ekonoxexxa
#
#     polarity_score  polarity
# 1               14  positive
# 2                8  positive
# 3                6  positive
# 4                6  positive
# 5                5  positive
# 6                5  positive
# 7                5  positive
# 8                4  positive
# 9                4  positive
# 10               4  positive

# %%
pd.set_option('display.max_colwidth', 3000)
negative_tweets = tweets[tweets['polarity'] == 'negative']
negative_tweets = negative_tweets[['text_clean', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=True)[0:10].reset_index(drop = True)
negative_tweets.index += 1
negative_tweets[0:20]
# Out:
#                                                                                                                                                                                                                                                                      text_clean  \
# 1                                                                                  bnikitalonte tau si bjorkaxexxxefxbxfnnayo dong polri periksa nikitalonte mana tau infonya benarnnsekalian tanyankapan siap masuk sel khan sudah menyandang status tersangka tuh nikitalonte
# 2                                                                                                                                                      b kata bjorka bong saya hacker mau beli akun tele kamu bisa  nnkan ketauan tololnya  bohongnya plisi siberxfxfxaxaxfxfxx
# 3                                                                                                                                                                                                                                    bhantu bjorka akan menyerang pejabat korup
# 4                                                                                                                                                    b fix isu bjorka udah basi ndak menarik lagi karena udah ndak jelas dimainkan untuk pengalihan isu politis pansos dllxexxa
# 5   bsaya bertanyatanya apakah  hanya musuh pemerintah indonesia untuk cybernya lalu kok dataxcxb rahasia negara hanya soal data pemerintah saat ini saja dan data wni lalu data rahasia negara tahun bahulanya mana saya jadi berpikirxcxb jgnxcxb si  ini hanya hacker kaleng
# 6      bdulu ada akun poconggg trus yang barusan bjorka lalu akun ini nntapi cuma protes di akun ini kenapa ini cuma soal keterpihakan kebetulan anda berpihak aja maka merasa risih nncreepy internet emang creepy nberlindung dibalik anon trus berbuat aneh tuh emang creepy
# 7                                                                                                                                                    b di tengah bjorka bocorkan data para pejabat dpr resmi sahkan uu perlindungan data pribadinntinggal mendesak rinmengxexxa
# 8                                                                                                                                              b polisi nyari bjorka  bulan sampe mesti pake penangkapan settingan netijen nyari identitas natalie ganyampe seminggu kebonxexxa
# 9                                                                                                                bhalo nyonya saya tidak punya banyak waktu untuk melayani anda karena anda hanya mencari nama yang baik untuk menutupi masa lalu anda yang buruk ujar bjorkann
# 10                                                                                                                                                                   b ini gatau kasus sambo sama bjorka ketinggalan wah gila si  setelah pandemi panjang malah banyak sinetron
#
#     polarity_score  polarity
# 1              -19  negative
# 2              -15  negative
# 3              -12  negative
# 4              -11  negative
# 5              -11  negative
# 6              -10  negative
# 7              -10  negative
# 8              -10  negative
# 9              -10  negative
# 10             -10  negative

# %% [markdown]
# ##Visualize word cloud
# Word cloud merupakan salah satu metode untuk menampilkan data teks secara visual. Grafik ini populer dalam text mining karena mudah dipahami.

# %%
# Visualize word cloud

list_words=''
for tweet in tweets['text_preprocessed']:
    for word in tweet:
        list_words += ' '+(word)

wordcloud = WordCloud(width = 600, height = 400, background_color = 'black', min_font_size = 10).generate(list_words)
fig, ax = plt.subplots(figsize = (8, 6))
ax.set_title('Word Cloud of Tweets Data', fontsize = 18)
ax.grid(False)
ax.imshow((wordcloud))
fig.tight_layout(pad=0)
ax.axis('off')
plt.show()

# %% [markdown]
# #Tugas
# Silahkan kalian labeling data yang sudah di crawling pada hari ke 2 kemarin sebagai mini project!
#
# kemudian simpan hasilnya dalam csv!

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Contoh Data: DataFrame berisi teks tweet yang telah dipreproses
tweets = pd.DataFrame({
    'text_preprocessed': [
        ['Robby', 'Saidi', 'Prasetyo'],
        ['Universitas ', 'Indraprasta', 'PGRI', 'python'],
        ['data', 'DIO', 'is', 'exciting'],
        ['GENTHA', 'data', 'visualization'],
        ['natural', 'language', 'processing', 'nlp', 'with', 'Diki'],
    ]
})

# Menggabungkan semua kata ke dalam satu string
list_words = ''
for tweet in tweets['text_preprocessed']:
    for word in tweet:
        list_words += ' ' + word

# Membuat Word Cloud
wordcloud = WordCloud(width=600, height=400, background_color='black', min_font_size=10).generate(list_words)

# Menampilkan Word Cloud
fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title('Word Cloud of Tweets Data', fontsize=18)
ax.grid(False)
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis('off')  # Menghilangkan sumbu
fig.tight_layout(pad=0)  # Menghilangkan padding
plt.show()

# %%
import requests
from bs4 import BeautifulSoup
import time

# Mulai dari URL utama
base_url = "https://www.kompas.com/"
visited_urls = set()
articles = []

# Fungsi untuk mendapatkan label kategori dari halaman
def get_category(soup):
    category = ""
    # Mencoba mencari kategori berdasarkan struktur halaman (misalnya pada kelas tertentu)
    category_tag = soup.find("meta", {"name": "section"})
    if category_tag:
        category = category_tag.get("content", "")
    return category

# Fungsi crawl untuk merayapi halaman
def crawl(url, depth=0, max_depth=2):
    if depth > max_depth or url in visited_urls:
        return

    print(f"Crawling: {url}")
    visited_urls.add(url)

    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, "html.parser")

        # Ambil kategori artikel dari halaman
        category = get_category(soup)

        # Ambil judul artikel dan link
        for item in soup.find_all("h3", class_="article__title"):
            title = item.get_text(strip=True)
            link = item.find("a")["href"]
            articles.append({"title": title, "link": link, "category": category})

        # Cari tautan lain untuk di-crawl
        for link in soup.find_all("a", href=True):
            full_link = link["href"]
            if full_link.startswith(base_url):  # Filter tautan internal
                crawl(full_link, depth + 1, max_depth)  # Rekursi

        time.sleep(1)  # Tambahkan jeda untuk menghindari server overload

    except Exception as e:
        print(f"Error crawling {url}: {e}")

# Mulai crawling dari halaman utama
crawl(base_url)

# Menampilkan hasil dengan label kategori
print("Beberapa artikel yang berhasil di-crawl:")
for article in articles[:10]:  # Menampilkan 10 artikel pertama
    print(f"Title: {article['title']}")
    print(f"Link: {article['link']}")
    print(f"Category: {article['category']}")
    print("-" * 40)
# Out:
# Crawling: https://www.kompas.com/
# Crawling: https://www.kompas.com/feedback
# Crawling: https://www.kompas.com/global
# Crawling: https://www.kompas.com/topik-pilihan/list/7782/kalbe-health-corner
# Crawling: https://www.kompas.com/cekfakta
# Crawling: https://www.kompas.com/konsultasihukum
# Crawling: https://www.kompas.com/hype
# Crawling: https://www.kompas.com/motogp
# Crawling: https://www.kompas.com/badminton
# Crawling: https://www.kompas.com/sports
# Crawling: https://www.kompas.com/tren?source=navbar
# Crawling: https://www.kompas.com/properti
# Crawling: https://www.kompas.com/food?source=navbar
# Crawling: https://www.kompas.com/food/resep
# Crawling: https://www.kompas.com/food/tips-kuliner
# Crawling: https://www.kompas.com/food/food-news
# Crawling: https://www.kompas.com/food/food-story
# Crawling: https://www.kompas.com/food/tempat-makan
# Crawling: https://www.kompas.com/food/gallery
# Crawling: https://www.kompas.com/food/panduan-kuliner-yogyakarta
# Crawling: https://www.kompas.com/edu
# Crawling: https://www.kompas.com/skola
# Crawling: https://www.kompas.com/parapuan?source=navbar
# Crawling: https://www.kompas.com/sains?source=navbar
# Crawling: https://www.kompas.com/homey?source=navbar
# Crawling: https://www.kompas.com/global?source=kompascom&medium=footer
# Crawling: https://www.kompas.com/tren?source=kompascom&medium=footer
# Crawling: https://www.kompas.com/hype?source=kompascom&medium=footer
# Crawling: https://www.kompas.com/homey?source=kompascom&medium=footer
# Crawling: https://www.kompas.com/food?source=kompascom&medium=footer
# Crawling: https://www.kompas.com/parapuan?source=kompascom&medium=footer
# Crawling: https://www.kompas.com/topik-pilihan?source=kompascom&medium=footer
# Crawling: https://www.kompas.com/global/read/2024/11/13/100720270/as-konfirmasi-tentara-korea-utara-mulai-terlibat-operasi-tempur-bersama
# Crawling: https://www.kompas.com/global/copy/2024/11/13/100720270/as-konfirmasi-tentara-korea-utara-mulai-terlibat-operasi-tempur-bersama
# Crawling: https://www.kompas.com/topik-pilihan/list/6959/perang-rusia-vs-ukraina
# Crawling: https://www.kompas.com/tag/tentara-korea-utara
# Crawling: https://www.kompas.com/global/read/2024/11/10/120000270/putin-tandatangani-perjanjian-pertahanan-bersama-dengan-korea-utara
# Crawling: https://www.kompas.com/global/read/2024/11/05/124500970/tentara-korea-utara-yang-akan-berperang-di-ukraina-dilaporkan-tak
# Crawling: https://www.kompas.com/hype/read/2024/11/13/185500566/lirik-lagu-hang-on-to-your-life-the-doors
# Crawling: https://www.kompas.com/hype/read/2024/11/13/185000366/lirik-dan-chord-lagu-wandering-musician-the-doors
# Crawling: https://www.kompas.com/hype/read/2024/11/13/184632466/lirik-dan-chord-lagu-im-horny-im-stoned-the-doors
# Crawling: https://www.kompas.com/hype/read/2024/11/13/183731366/ador-tanggapi-kabar-newjeans-ancam-akhiri-kontrak-eksklusif
# Crawling: https://www.kompas.com/hype/read/2024/11/13/183337066/dikeluarkan-dari-the-groove-keuangan-rieka-roslan-membaik-berkat-jadi-juri
# Crawling: https://www.kompas.com/hype/read/2024/11/13/094607366/tak-berharap-batara-kembalikan-rp-13-miliar-fuji-uang-bisa-dicari
# Crawling: https://www.kompas.com/hype/read/2024/11/12/220243566/catatan-terakhir-ratu-elizabeth-ii-terungkap-hanya-berisi-lima-kata
# Crawling: https://www.kompas.com/hype/read/2024/11/13/114452066/denny-sumargo-buka-suara-usai-dilaporkan-farhat-abbas-ke-polisi
# Crawling: https://www.kompas.com/hype/read/2024/11/13/072658066/polisi-temukan-surat-di-apartemen-tempat-song-jae-rim-meninggal
# Crawling: https://www.kompas.com/hype/read/2024/11/13/120336766/ditangkap-polisi-saat-bersama-anak-andrew-andika-aku-ngerasa-gagal-sebagai
# Crawling: https://www.kompas.com/topik-pilihan/list/9268/100.hari.kerja.prabowo-gibran
# Crawling: https://www.kompas.com/global/read/2024/11/05/102922670/china-umumkan-prabowo-akan-berkunjung-akhir-pekan-ini-sebut-atas-undangan
# Crawling: https://www.kompas.com/topik-pilihan/list/9268/100.hari.kerja.prabowo-gibran?page=2
# Crawling: https://www.kompas.com/topik-pilihan/list/9268/100.hari.kerja.prabowo-gibran?page=3
# Crawling: https://www.kompas.com/topik-pilihan/list/9268/100.hari.kerja.prabowo-gibran?page=13
# Crawling: https://www.kompas.com/topik-pilihan/list/9032/pilkada.2024
# Crawling: https://www.kompas.com/topik-pilihan/list/9032/pilkada.2024?page=2
# Crawling: https://www.kompas.com/topik-pilihan/list/9032/pilkada.2024?page=3
# Crawling: https://www.kompas.com/topik-pilihan/list/9032/pilkada.2024?page=19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0ddccd4c94b0> in <cell line: 52>()
#      50
#      51 # Mulai crawling dari halaman utama
# ---> 52 crawl(base_url)
#      53
#      54 # Menampilkan hasil dengan label kategori
#
# <ipython-input-10-0ddccd4c94b0> in crawl(url, depth, max_depth)
#      42             full_link = link["href"]
#      43             if full_link.startswith(base_url):  # Filter tautan internal
# ---> 44                 crawl(full_link, depth + 1, max_depth)  # Rekursi
#      45
#      46         time.sleep(1)  # Tambahkan jeda untuk menghindari server overload
#
# <ipython-input-10-0ddccd4c94b0> in crawl(url, depth, max_depth)
#      44                 crawl(full_link, depth + 1, max_depth)  # Rekursi
#      45
# ---> 46         time.sleep(1)  # Tambahkan jeda untuk menghindari server overload
#      47
#      48     except Exception as e:
#
# KeyboardInterrupt:
